# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
df=pd.read_csv('Data/SV 2016 correlation data.csv', sep=',')

# %%
df.head()
# Out:
#    ID New Model Purchased (Alpha Order)  \
# 0   1                  Chrysler 200 Sdn
# 1   3                  Chrysler 200 Sdn
# 2   4                  Chrysler 200 Sdn
# 3   5                  Chrysler 200 Sdn
# 4   6                  Chrysler 200 Sdn
#
#   New Model Purchased - Make/Model/Series (Alpha Order)  \
# 0      Chrysler 200 Limited Sedan (2016 MY) - 111413
# 1      Chrysler 200 Limited Sedan (2016 MY) - 111413
# 2      Chrysler 200 Limited Sedan (2016 MY) - 111413
# 3      Chrysler 200 Limited Sedan (2016 MY) - 111413
# 4      Chrysler 200 Limited Sedan (2016 MY) - 111413
#
#   New Model Purchased - Brand New Model Segment         Segmentation 1  \
# 0                    Chrysler      Mid-Size Car  Standard Mid-Size Car
# 1                    Chrysler      Mid-Size Car  Standard Mid-Size Car
# 2                    Chrysler      Mid-Size Car  Standard Mid-Size Car
# 3                    Chrysler      Mid-Size Car  Standard Mid-Size Car
# ...

# %%
plt.matshow(df.corr())
df.corr().to_csv('results/overall correlation matrix.csv')

# %%
sedanCorr=df.loc[(df['Match Segment'] == 'Sedan')].corr()
plt.matshow(df.loc[(df['Match Segment'] == 'Sedan')].corr())
sedanCorr.to_csv('results/sedan correlation matrix.csv')

# %%
suvCorr=df.loc[(df['Match Segment'] == 'SUV')].corr()
plt.matshow(df.loc[(df['Match Segment'] == 'SUV')].corr())
suvCorr.to_csv('resluts/suv correlation matrix.csv')

# %%
plt.matshow(df.loc[(df['Match Segment'] == 'Sedan')].corr()-df.loc[(df['Match Segment'] == 'SUV')].corr())

# %%
delta=df.loc[(df['Match Segment'] == 'Sedan')].corr()-df.loc[(df['Match Segment'] == 'SUV')].corr()

# %%
delta.describe()
# Out:
# /usr/local/lib/python2.7/dist-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#               ID    Cluster   Category  Driving Area  Research Sources  \
# count  50.000000  50.000000  50.000000     50.000000         50.000000
# mean    0.015799   0.048105   0.007452     -0.006545         -0.013136
# std     0.112026   0.041607   0.041756      0.026946          0.023252
# min    -0.249763  -0.068246  -0.065672     -0.043984         -0.068148
# 25%          NaN        NaN        NaN           NaN               NaN
# 50%          NaN        NaN        NaN           NaN               NaN
# 75%          NaN        NaN        NaN           NaN               NaN
# max     0.215053   0.114993   0.101581      0.137772          0.053897
#
#        Consumer Reports  Buyer Innovation Tendency  \
# count         50.000000                  50.000000
# mean          -0.021807                   0.004141
# ...

# %%
plt.matshow(delta)

# %%
plt.matshow(df.loc[(df['Cluster'] == 0)].corr()-df.corr())

# %%
df.corr().max()
# Out:
# ID                                                                               1.0
# Cluster                                                                          1.0
# Category                                                                         1.0
# Driving Area                                                                     1.0
# Research Sources                                                                 1.0
# Consumer Reports                                                                 1.0
# Buyer Innovation Tendency                                                        1.0
# I'm Curious and Open to Experiences                                              1.0
# Driving is one of my favorite things to do                                       1.0
# When I drive for fun, I mainly prefer to relax and listen to music or talk       1.0
# I want vehicles that provide that open-air driving experience                    1.0
# ...
